# %% [markdown]
# Track 1: Working with existing questions and datasets
#
# Case Study 2: How Can a Wellness Technology Company Play It Smart?

# %% [markdown]
# ## Table of Contents
#
#
# * [1. Ask](#Ask_1)
#     * [1.1 Guiding Questions](#Guiding_Questions_1_1)
#     * [1.2 Key Tasks](#Key_Tasks_1_2)
#     * [1.3 Deliverable](#Deliverable_1_3)
# * [2. Prepare](#Prepare_2)
#     * [2.1 Guiding Questions](#Guiding_Questions_2_1)
#     * [2.2 Deliverable](#Deliverable_2_2)
# * [3. Process](#Prepare_3)
#     * [3.1 Load Libraries and datasets](#Load_Libraries_and_datasets_3_3)
#     * [3.4 Clean dataset](#Clean_data_3_4)
# * [4. Analyze](#Analyze_4)
#     * [4.1 Activity vs. Calories](#4_1)
#     * [4.2 Sedentary Behavior Impact](#4_2)
#     * [4.3 User Segmentation](#4_3)
#     * [4.4 Statistical Testing](#4_4)
#     * [4.5 Trend Analysis](#4_5)
#     * [4.6 Activity Efficiency](#4_6)
#     * [4.7 Caloric Goals](#4_7)
# * [5. Share and Act](#Share_and_Act_5)
#     * [5.1 Conclusion](#Conclusion_5_1)
#     * [5.2 Application of Insights](#Application_of_Insights_5_2)
#     * [5.3 Next Steps](#Next_Steps_5_3)

# %% [markdown]
# # <span >  1. Ask </span>  <a class="anchor" id="Ask_1"></a>
# ### 1.1 Guiding Questions <a class="anchor" id="Guiding_Questions_1_1"></a>
# #### - What is the problem you are trying to solve?
# - The primary problem is to identify growth opportunities for Bellabeat by analyzing smart device fitness data. By understanding how consumers are currently using their smart devices, Bellabeat aims to refine its marketing strategies to better target potential customers and engage existing ones.
#
# #### - How can your insights drive business decisions?
# - Highlight the most popular features of Bellabeat products.
# - Identify potential areas for product improvement or development.
# - Showcase the best-performing marketing channels, thus guiding budget allocation.
# - Uncover patterns in sales and product usage, allowing for more targeted marketing campaigns.
# - Provide feedback on user preferences, which can influence future product designs or updates.
#
# ### 1.1 Key Tasks <a class="anchor" id="Key_Tasks_1_2"></a>
# #### Identify the business task:
# - The business task is to analyze the smart device usage data of Bellabeat products to derive insights that can guide and refine the company's marketing strategy. This involves understanding consumer behaviors, preferences, and engagement levels to uncover potential growth areas for the company.
# #### Consider key stakeholders:
# - Urška Sršen: As the CCO and cofounder, she will be keenly interested in how the insights can be utilized for product improvement and innovation.
# - Sando Mur: As a cofounder and a key member of the executive team, he will be interested in how these insights can drive business growth and strategic decisions.
# - Bellabeat marketing analytics team: They will be directly involved in collecting, analyzing, and implementing the insights derived from the data analysis.
# - End Users: Understanding their preferences and behaviors is crucial as it will influence product updates and new launches.
# - Sales and Marketing Teams: Insights will directly influence their campaigns, strategies, and potentially their budgets.

# %% [markdown]
# ### 1.3 Deliverable <a class="anchor" id="Deliverable_1_3"></a>
# #### A clear statement of the business task:
#
# - "Bellabeat seeks to harness insights from smart device usage data to understand consumer behaviors and preferences. By analyzing this data, we aim to identify growth opportunities, optimize marketing strategies, and potentially influence product design and features. These insights will be instrumental in guiding Bellabeat's marketing decisions, budget allocations, and product development efforts to ensure alignment with consumer needs and preferences, ultimately driving business growth."

# %% [markdown]
# # <span>  2. Prepare </span>  <a class="anchor" id="Prepare_2"></a>
# ### 3.1 Guiding Questions <a class="anchor" id="Guiding_Questions_2_1"></a>
# #### - Where is your data stored?
# Stored locally on the company's PC
# #### - How is the data organized? Is it in long or wide format?
# Most files have Long format (one column of few) both versions Wide and Long.
# #### - Are there issues with bias or credibility in this data?
# 1. **Sample Size and Representation**:
#     - The data consists of only thirty Fitbit users. Depending on the diversity of these users, the sample may not be representative of the broader population of Fitbit users or smart device users in general. For instance, if all thirty users come from the same geographic location, age group, or fitness level, the data could be heavily biased.
#
# 2. **Data Collection Method**:
#     - How were these thirty users selected? If they were not randomly selected, there might be a selection bias.
#     - Did users know their data was being used for this analysis? If so, they might have changed their behavior (Hawthorne Effect), which could introduce bias.
#
# 3. **Data Completeness**:
#     - If there are significant missing values or gaps in the data, it might not provide a complete picture of user habits.
#
# 4. **Credibility of the Source**:
#     - The data comes from Kaggle, which is reputable, but the original source is "Mobius." The credibility would depend on how well Mobius collected, cleaned, and shared the data. Verification of the authenticity and accuracy of the data is essential.
#
# 5. **Potential for Confounding Factors**:
#     - There might be external factors influencing the users' fitness habits that aren't captured in the data. For instance, users might also use other fitness apps or devices alongside Fitbit, or external events (like holidays, personal events, or even weather changes) might impact their activity levels.
#
# 6. **User Consent and Privacy**:
#     - It's mentioned that the users consented to the submission of their data. However, ensuring that the data is entirely anonymized and doesn't violate any privacy regulations or ethical standards is crucial.
#
# 7. **Generalization**:
#     - Given that this is data from a Fitbit device, any insights or patterns observed might not necessarily apply to users of other smart devices or Bellabeat's products.
#
# In summary, while the FitBit Fitness Tracker Data provides valuable insights into user habits, it's essential to approach the analysis with caution and be aware of potential biases and limitations. Any conclusions or recommendations based on this data should be made tentatively, acknowledging these limitations.
# #### - Does your data ROCCC? Yes.
# #### - How are you addressing licensing, privacy, security, and accessibility?
#
# 1. **Licensing**:
#     - The FitBit Fitness Tracker Data is marked as "CC0: Public Domain" on Kaggle. This means that the data is free to use for any purpose, including commercial use, without needing to provide attribution to the original creator. However, it's always good practice to cite the source when presenting findings or insights.
#     - We should also ensure that we aren't violating any terms of use of the Fitbit platform itself, even if the dataset is publicly available.
#
# 2. **Privacy**:
#     - The dataset is said to be from consenting users, which is a good start. But to ensure privacy:
#       - We should confirm that all personally identifiable information (PII) has been removed or anonymized. This includes names, addresses, or any unique identifiers that can trace back to an individual.
#       - When presenting or sharing insights, aggregate data should be used rather than individual data points to prevent any potential identification of users.
#
# 3. **Security**:
#     - Once the data is downloaded, it should be stored securely. A few measures include:
#       - Storing the data in encrypted formats or secure databases.
#       - Limiting access to only those who need to work with the data.
#       - Regularly backing up the data to prevent loss.
#       - Ensuring that data transmission (if needed) is done through secure channels.
#
# 4. **Accessibility**:
#     - While it's essential to secure the data, it's equally important to ensure that authorized team members can access it easily for analysis purposes.
#       - This might involve storing it on a shared, secure cloud platform or a company server.
#       - Proper documentation of the dataset, including its source, structure, and any cleaning or preprocessing steps taken, should be maintained. This helps in ensuring that any analyst or stakeholder can understand and work with the data without confusion.
#
# In conclusion, by ensuring proper licensing acknowledgment, maintaining user privacy, securing the data, and providing controlled accessibility, we can responsibly and ethically work with the FitBit Fitness Tracker Data.
# #### - How did you verify the data’s integrity?
# - The data is downloaded from a reputable source, in this case, Kaggle.
# #### - How does it help you answer your question?
# - Reliable Insights, Stakeholder Trust
# #### - Are there any problems with the data?
# - It is not current, it is only for 2 months long

# %% [markdown]
# ### 2.2 Deliverable <a class="anchor" id="Deliverable_2_2"></a>
# - A description of dataset sources used
# | # | Dataset Name                     | Description                                                                                               | Users  |
# |---|----------------------------------|-----------------------------------------------------------------------------------------------------------|-------------|
# | 1 | Daily Activity                   | Tracks steps, distance, intensities, and calories.                                                        | 33/31       |
# | 2 | Daily Calories                   | Records daily calorie consumption.                                                                        | 33/31       |
# | 3 | Daily Intensity                  | Measures activity intensity in minutes and distance, categorized into different intensity levels.          | 33/31       |
# | 4 | Daily Steps                      | Logs the number of steps taken daily.                                                                     | 33/31       |
# | 5 | Heart Rate Logs                  | Provides specific day and time logs of heart rates.                                                       | 7/varied    |
# | 6 | Hourly Activity                  | - Calories: Tracks hourly calories burned. <br> - Intensities: Records hourly intensity. <br> - Steps: Monitors hourly steps. | 33/31       |
# | 7 | Minute-by-minute Data            | - Calories, Intensity, METs, Steps: Various minute-wise logs in two formats (row/column).                 | 33/31       |
# | 8 | Sleep Data                       | - Minute Sleep: Logs sleep by the minute. <br> - Daily Sleep Logs: Records daily sleep metrics.           | 24/31       |
# | 9 | Weight Tracking                  | Tracks daily weight in kg/lbs and BMI. Notes on manual reporting by some users.                           | 8/30        |

# %% [markdown]
# # <span >  3. Process </span>  <a class="anchor" id="Process_3"></a>
# ### 3.1 Key Tasks <a class="anchor" id="Key_Task_3_1"></a>
# - 1. Check the data for errors.
# - 2. Choose your tools.
# - 3. Transform the data so you can work with it effectively.
# - 4. Document the cleaning process.
#
# ### 3.2 Deliverable <a class="anchor" id="Deliverable_3_2"></a>
# - Documentation of any cleaning or manipulation of data. It is the below steps:

# %% [markdown]
# ### 3.3 Load Libraries and datasets <a class="anchor" id="Load_Libraries_and_datasets_3_3"></a>

# %%
# import data science analysis libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import datetime as dt
import math
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# /kaggle/input/fitbit/Fitabase Data 4.12.16-5.12.16/minuteCaloriesNarrow_merged.csv
# /kaggle/input/fitbit/Fitabase Data 4.12.16-5.12.16/weightLogInfo_merged.csv
# /kaggle/input/fitbit/Fitabase Data 4.12.16-5.12.16/sleepDay_merged.csv
# /kaggle/input/fitbit/Fitabase Data 4.12.16-5.12.16/dailyIntensities_merged.csv
# /kaggle/input/fitbit/Fitabase Data 4.12.16-5.12.16/minuteIntensitiesWide_merged.csv
# /kaggle/input/fitbit/Fitabase Data 4.12.16-5.12.16/minuteMETsNarrow_merged.csv
# /kaggle/input/fitbit/Fitabase Data 4.12.16-5.12.16/dailyCalories_merged.csv
# /kaggle/input/fitbit/Fitabase Data 4.12.16-5.12.16/hourlyCalories_merged.csv
# /kaggle/input/fitbit/Fitabase Data 4.12.16-5.12.16/heartrate_seconds_merged.csv
# /kaggle/input/fitbit/Fitabase Data 4.12.16-5.12.16/minuteSleep_merged.csv
# /kaggle/input/fitbit/Fitabase Data 4.12.16-5.12.16/hourlyIntensities_merged.csv
# /kaggle/input/fitbit/Fitabase Data 4.12.16-5.12.16/hourlySteps_merged.csv
# ...

# %% [markdown]
# #### We will focus on:
# - DailyActivitiy
# - DailySleep
# - DailySteps
# - DailyCalories
# - DailyWeight

# %%
# read data from csv file
daily_activity = pd.read_csv('/kaggle/input/fitbit/Fitabase Data 4.12.16-5.12.16/dailyActivity_merged.csv')
daily_calories = pd.read_csv('/kaggle/input/fitbit/Fitabase Data 4.12.16-5.12.16/dailyCalories_merged.csv')
daily_steps = pd.read_csv('/kaggle/input/fitbit/Fitabase Data 4.12.16-5.12.16/dailySteps_merged.csv')
daily_sleep = pd.read_csv('/kaggle/input/fitbit/Fitabase Data 4.12.16-5.12.16/sleepDay_merged.csv')
# daily_heart = pd.read_csv('/kaggle/input/fitbit/Fitabase Data 4.12.16-5.12.16/heartrate_seconds_merged.csv') 
# daily_weight = pd.read_csv('Fitabase_data/weightLogInfo_merged.csv') # will not be used

# %% [markdown]
# ### 3.4 Clean data <a class="anchor" id="Clean_data_3_4"></a>
# ### 3.4.1 Check number of Unique Users (How many users are there?) <a class="anchor" id="3_4_1"></a>
# ###

# %%
# Check unique users id
print("daily_activity: ", daily_activity['Id'].nunique()) # 33 Users
print("daily_calories: ", daily_calories['Id'].nunique()) # 33 Users
print("daily_steps: ",daily_steps['Id'].nunique()) # 33 Users
print("daily_sleep: ",daily_sleep['Id'].nunique()) # 24 Users
# print("daily_weight: ",daily_weight['Id'].nunique()) # 8 Users
# print("daily_heart: ", daily_heart['Id'].nunique()) # 14 Users
# Out:
# daily_activity:  33
# daily_calories:  33
# daily_steps:  33
# daily_sleep:  24

# %%
# Check for duplicates
print("daily_activity: ",daily_activity.duplicated().sum()) # 0
print("daily_calories: ",daily_calories.duplicated().sum()) # 0
print("daily_steps: ",daily_steps.duplicated().sum()) # 0
print("daily_sleep: ",daily_sleep.duplicated().sum()) # 3

# Remove duplicates in daily_sleep dataset
daily_sleep.drop_duplicates(inplace=True)
print("daily_sleep: ",daily_sleep.duplicated().sum()) # 0
# Out:
# daily_activity:  0
# daily_calories:  0
# daily_steps:  0
# daily_sleep:  3
# daily_sleep:  0

# %%
# check null values
print("daily_activity: ",daily_activity.isnull().sum()) 
# print("daily_calories: ",daily_calories.isnull().sum()) 
# print("daily_steps: ",daily_steps.isnull().sum()) 
# print("daily_sleep: ",daily_sleep.isnull().sum())
# Out:
# daily_activity:  Id                          0
# ActivityDate                0
# TotalSteps                  0
# TotalDistance               0
# TrackerDistance             0
# LoggedActivitiesDistance    0
# VeryActiveDistance          0
# ModeratelyActiveDistance    0
# LightActiveDistance         0
# SedentaryActiveDistance     0
# VeryActiveMinutes           0
# FairlyActiveMinutes         0
# LightlyActiveMinutes        0
# SedentaryMinutes            0
# Calories                    0
# dtype: int64

# %% [markdown]
# ### 3.4.2 Clean and rename columns for consistency <a class="anchor" id="3_4_2"></a>

# %%
# Change all columns to lowercase
daily_activity.columns = daily_activity.columns.str.lower()
daily_calories.columns = daily_calories.columns.str.lower()
daily_steps.columns = daily_steps.columns.str.lower()
daily_sleep.columns = daily_sleep.columns.str.lower()
daily_activity.head() # Check one of the tables
# Out:
#            id activitydate  totalsteps  totaldistance  trackerdistance  \
# 0  1503960366    4/12/2016       13162           8.50             8.50
# 1  1503960366    4/13/2016       10735           6.97             6.97
# 2  1503960366    4/14/2016       10460           6.74             6.74
# 3  1503960366    4/15/2016        9762           6.28             6.28
# 4  1503960366    4/16/2016       12669           8.16             8.16
#
#    loggedactivitiesdistance  veryactivedistance  moderatelyactivedistance  \
# 0                       0.0                1.88                      0.55
# 1                       0.0                1.57                      0.69
# 2                       0.0                2.44                      0.40
# 3                       0.0                2.14                      1.26
# 4                       0.0                2.71                      0.41
#
#    lightactivedistance  sedentaryactivedistance  veryactiveminutes  \
# ...

# %%
daily_activity.describe()
# Out:
#                  id    totalsteps  totaldistance  trackerdistance  \
# count  9.400000e+02    940.000000     940.000000       940.000000
# mean   4.855407e+09   7637.910638       5.489702         5.475351
# std    2.424805e+09   5087.150742       3.924606         3.907276
# min    1.503960e+09      0.000000       0.000000         0.000000
# 25%    2.320127e+09   3789.750000       2.620000         2.620000
# 50%    4.445115e+09   7405.500000       5.245000         5.245000
# 75%    6.962181e+09  10727.000000       7.712500         7.710000
# max    8.877689e+09  36019.000000      28.030001        28.030001
#
#        loggedactivitiesdistance  veryactivedistance  moderatelyactivedistance  \
# count                940.000000          940.000000                940.000000
# mean                   0.108171            1.502681                  0.567543
# std                    0.619897            2.658941                  0.883580
# ...

# %%
# make all daily_activity date format consistent
daily_activity['activitydate'] = pd.to_datetime(daily_activity['activitydate'], format='%m/%d/%Y')
daily_calories['activityday'] = pd.to_datetime(daily_calories['activityday'], format='%m/%d/%Y')
daily_steps['activityday'] = pd.to_datetime(daily_steps['activityday'], format='%m/%d/%Y')
daily_sleep['sleepday'] = pd.to_datetime(daily_sleep['sleepday'], format='%m/%d/%Y %I:%M:%S %p') # format is different from other dataframes
# daily_sleep['sleepday'] = daily_sleep['sleepday'].dt.date

# %% [markdown]
# ### 3.4.3 Merge daily activity daily calories, and daile sleep <a class="anchor" id="3_4_3"></a>

# %%
daily_activity.head()
# Out:
#            id activitydate  totalsteps  totaldistance  trackerdistance  \
# 0  1503960366   2016-04-12       13162           8.50             8.50
# 1  1503960366   2016-04-13       10735           6.97             6.97
# 2  1503960366   2016-04-14       10460           6.74             6.74
# 3  1503960366   2016-04-15        9762           6.28             6.28
# 4  1503960366   2016-04-16       12669           8.16             8.16
#
#    loggedactivitiesdistance  veryactivedistance  moderatelyactivedistance  \
# 0                       0.0                1.88                      0.55
# 1                       0.0                1.57                      0.69
# 2                       0.0                2.44                      0.40
# 3                       0.0                2.14                      1.26
# 4                       0.0                2.71                      0.41
#
#    lightactivedistance  sedentaryactivedistance  veryactiveminutes  \
# ...

# %%
daily_calories.head()
# Out:
#            id activityday  calories
# 0  1503960366  2016-04-12      1985
# 1  1503960366  2016-04-13      1797
# 2  1503960366  2016-04-14      1776
# 3  1503960366  2016-04-15      1745
# 4  1503960366  2016-04-16      1863

# %%
daily_sleep.head()
# Out:
#            id   sleepday  totalsleeprecords  totalminutesasleep  \
# 0  1503960366 2016-04-12                  1                 327
# 1  1503960366 2016-04-13                  2                 384
# 2  1503960366 2016-04-15                  1                 412
# 3  1503960366 2016-04-16                  2                 340
# 4  1503960366 2016-04-17                  1                 700
#
#    totaltimeinbed
# 0             346
# 1             407
# 2             442
# 3             367
# 4             712

# %%
# merge daily_activity and daily_calories on Id and date columns
daily_activity_calories = pd.merge(
    daily_activity, daily_calories,left_on=['id', 'activitydate'], right_on=['id', 'activityday'],how='inner')
daily_activity_calories.head()
# merged_data daily_sleep
daily_activity_calories = pd.merge(daily_activity_calories, daily_sleep,left_on=['id','activitydate'], right_on=['id', 'sleepday'], how='inner')
daily_activity_calories.head()
# Out:
#            id activitydate  totalsteps  totaldistance  trackerdistance  \
# 0  1503960366   2016-04-12       13162           8.50             8.50
# 1  1503960366   2016-04-13       10735           6.97             6.97
# 2  1503960366   2016-04-15        9762           6.28             6.28
# 3  1503960366   2016-04-16       12669           8.16             8.16
# 4  1503960366   2016-04-17        9705           6.48             6.48
#
#    loggedactivitiesdistance  veryactivedistance  moderatelyactivedistance  \
# 0                       0.0                1.88                      0.55
# 1                       0.0                1.57                      0.69
# 2                       0.0                2.14                      1.26
# 3                       0.0                2.71                      0.41
# 4                       0.0                3.19                      0.78
#
#    lightactivedistance  sedentaryactivedistance  ...  fairlyactiveminutes  \
# ...

# %% [markdown]
# # <span Analyze>  4. Analyze </span>  <a class="anchor" id="Analyze_4"></a>

# %% [markdown]
# ### 4.1 Activity vs. Calories <a class="anchor" id="4_1"></a>
# Calculate the correlation between total steps or very active minutes and calories burnt. This can provide insights into how activity levels influence caloric burn.

# %%
# Calculate the correlation between total steps and calories burnt
correlation_steps_calories = daily_activity_calories['totalsteps'].corr(daily_activity_calories['calories_y'])

# Calculate the correlation between very active minutes and calories burnt
correlation_active_minutes_calories = daily_activity_calories['veryactiveminutes'].corr(daily_activity_calories['calories_y'])

print('Correlation between total steps and calories burnt: ', correlation_steps_calories)
print('Correlation between very active minutes and calories burnt: ', correlation_active_minutes_calories)
# Out:
# Correlation between total steps and calories burnt:  0.4063006759209672
# Correlation between very active minutes and calories burnt:  0.6111982924396088

# %% [markdown]
# - Both steps taken and very active minutes have a positive correlation with calories burnt, meaning as they increase, caloric burn tends to increase as well.
# - The intensity of activity (very active minutes) has a slightly stronger correlation with caloric burn than just the number of steps.
# - While these metrics provide insight into caloric burn, they don't capture the full picture. Other factors, like individual physiology and activities not measured by the device, also influence calories burnt.

# %% [markdown]
# ### 4.2 Sedentary Behavior Impact <a class="anchor" id="4_2"></a>
# Analyze how sedentary minutes influence calories burnt. It would be interesting to see if longer sedentary periods significantly decrease daily caloric burn.

# %%
# Descriptive Statistics of sedentary minutes
daily_activity_calories["sedentaryminutes"].describe()
# Out:
# count     410.000000
# mean      712.100000
# std       166.179395
# min         0.000000
# 25%       631.250000
# 50%       717.000000
# 75%       782.750000
# max      1265.000000
# Name: sedentaryminutes, dtype: float64

# %% [markdown]
# - Mean: On average, users are sedentary for about 991.2 minutes (or roughly 16.5 hours) a day.
# - Standard Deviation: The standard deviation is about 301.3 minutes, indicating there's a variability of around 5 hours in sedentary behavior among the users.
# - Min and Max: The range of sedentary minutes is from 0 to 1440 minutes (24 hours). This means that on some days, certain users were not sedentary at all, while on other days, some users were sedentary the entire day.
# - Quartiles:
#     - 25% of the data (1st quartile) have sedentary minutes below 729.75 minutes (or about 12.2 hours).
#     - The median (50% or 2nd quartile) is 1057.5 minutes, meaning half of the users have sedentary periods of about 17.6 hours or more per day.
#     - 75% of the data (3rd quartile) have sedentary minutes below 1229.5 minutes (or about 20.5 hours).
# - From these statistics, we can conclude that a significant portion of users' days is sedentary. The majority of users (as indicated by the median) are sedentary for more than 17 hours a day.

# %%
correlation_sedentaryminutes_calories = daily_activity_calories['sedentaryminutes'].corr(daily_activity_calories['calories_y'])
print("Correlation between sedentary minutes and calories burned: ", correlation_sedentaryminutes_calories)
# Out:
# Correlation between sedentary minutes and calories burned:  0.09865570579679844

# %% [markdown]
# - The negative value indicates that as the sedentary minutes increase, the calories burned tend to decrease, and vice versa.

# %%
# scatter plot sedentary minutes vs. calories
sns.scatterplot(x="sedentaryminutes", y="calories_y", data=daily_activity_calories)
# Out:
# <Axes: xlabel='sedentaryminutes', ylabel='calories_y'>

# %% [markdown]
# Given the scatter plot observation and the correlation coefficient:
#
# 1. **Slight Negative Trend**: The scatter plot's slight downward trend aligns with the negative correlation coefficient value, indicating that as sedentary behavior increases (more sedentary minutes), there's a trend for caloric burn to decrease. However, it's essential to emphasize that this trend is "slight," meaning that while there is a relationship, it isn't particularly pronounced.
#
# 2. **Weak Relationship**: The correlation value of approximately \(-0.107\) further reiterates the weak nature of this relationship. This means that sedentary minutes alone might not be the primary or only factor influencing caloric burn. Other elements, such as moments of intense activity, metabolic rate, or other non-tracked activities, are also at play.
#
# 3. **Interpretation in Context**: Given that the relationship is weak, it suggests that solely focusing on reducing sedentary behavior might not lead to substantial increases in caloric burn. While reducing sedentary behavior has other health benefits, if the primary goal is to increase caloric expenditure, it might be more effective to focus on increasing periods of moderate to intense activity.
#
# In summary, while there's a negative relationship between sedentary behavior and caloric burn, the relationship is weak, suggesting the influence of other significant factors in determining daily caloric expenditure.

# %% [markdown]
# ### 4.3 User Segmentation <a class="anchor" id="4_3"></a>
# - Divide the data into segments based on sedentary behavior. For example:
#     - Low sedentary: Less than 4 hours.
#     - Moderate sedentary: 4-8 hours.
#     - High sedentary: More than 8 hours.

# %%
def sedentary_segment(minutes):
    if minutes < 4*60:  # Less than 4 hours
        return "Low sedentary"
    elif 4*60 <= minutes <= 8*60:  # 4-8 hours
        return "Moderate sedentary"
    else:  # More than 8 hours
        return "High sedentary"

# Apply the function to the 'sedentaryminutes' column
daily_activity_calories['Sedentary_Segment'] = daily_activity_calories['sedentaryminutes'].apply(sedentary_segment)
average_caloric_burn_per_segment = daily_activity_calories.groupby('Sedentary_Segment')['calories_y'].mean().rename('Average Caloric Burn').reset_index()
print(average_caloric_burn_per_segment)
# Out:
#     Sedentary_Segment  Average Caloric Burn
# 0      High sedentary           2414.078329
# 1       Low sedentary            890.000000
# 2  Moderate sedentary           2365.666667

# %% [markdown]
# High Caloric Burn in Sedentary Behavior: Both "High sedentary" and "Moderate sedentary" groups have a significantly higher average caloric burn than the "Low sedentary" group. This is somewhat counterintuitive since we might expect that more sedentary behavior would lead to lower caloric burn.
#
# Minimal Difference between High and Moderate: The average caloric burn between the "High sedentary" and "Moderate sedentary" groups is very close, with the "Moderate sedentary" group being slightly higher. This suggests that the difference in sedentary behavior between these two groups doesn't significantly impact the caloric burn.
#
# Other Influencing Factors: Given that more sedentary behavior doesn't seem to correspond to a lower caloric burn, there are likely other significant factors influencing caloric burn. For instance, individuals in the "High sedentary" and "Moderate sedentary" groups might be engaging in short, intense activities that elevate their caloric burn for the day.
#
# Importance of Activity Intensity: The data might hint that the intensity of physical activity (even if for shorter durations) can have a significant impact on daily caloric burn. The "Low sedentary" group might be lacking these bursts of intense activity, leading to a much lower average caloric burn.
#
# Potential Data Limitations: It's essential to consider potential data limitations or biases. For instance, the device might not capture all types of activities equally, or there might be external factors not accounted for in the data that influence caloric burn.
#
# In summary, while sedentary behavior is an important aspect to consider, the data suggests that other factors, possibly including bursts of intense activity or individual metabolic rates, play a more crucial role in determining daily caloric burn. It emphasizes the importance of considering the entire activity profile of an individual rather than focusing solely on sedentary periods.

# %% [markdown]
# segmentation based on daily steps

# %%
daily_avg = daily_activity_calories.groupby('id').agg({
    'totalsteps': 'mean',
    'calories_y': 'mean',
    'totalminutesasleep': 'mean'  # Assuming 'totalsleeprecords' is the relevant column for sleep data
}).reset_index()

# Rename columns for clarity
daily_avg.columns = ['id', 'mean_daily_steps', 'mean_daily_calories', 'mean_daily_sleep']

daily_avg.head()
# Out:
#            id  mean_daily_steps  mean_daily_calories  mean_daily_sleep
# 0  1503960366      12405.680000          1872.280000        360.280000
# 1  1644430081       7967.750000          2977.750000        294.000000
# 2  1844505072       3477.000000          1676.333333        652.000000
# 3  1927972279       1490.000000          2316.200000        417.000000
# 4  2026352035       5618.678571          1540.785714        506.178571

# %%
# Define a function to categorize users based on their average daily steps
def classify_by_steps(average_steps):
    if average_steps < 5000:
        return "Sedentary"
    elif 5000 <= average_steps < 7500:
        return "Lightly active"
    elif 7500 <= average_steps < 10000:
        return "Fairly active"
    else:
        return "Very active"

# Apply the function to the 'mean_daily_steps' column to create a new 'Activity_Category' column
daily_avg['Activity_Category'] = daily_avg['mean_daily_steps'].apply(classify_by_steps)

# Display the updated dataframe with the new 'Activity_Category' column
daily_avg.head()
# Out:
#            id  mean_daily_steps  mean_daily_calories  mean_daily_sleep  \
# 0  1503960366      12405.680000          1872.280000        360.280000
# 1  1644430081       7967.750000          2977.750000        294.000000
# 2  1844505072       3477.000000          1676.333333        652.000000
# 3  1927972279       1490.000000          2316.200000        417.000000
# 4  2026352035       5618.678571          1540.785714        506.178571
#
#   Activity_Category
# 0       Very active
# 1     Fairly active
# 2         Sedentary
# 3         Sedentary
# 4    Lightly active

# %%
# group by percentage:
import pandas as pd

# Group by 'Activity_Category' and count each group
user_type_percent = daily_avg.groupby('Activity_Category').size().reset_index(name='total')

# Calculate the total number of users
user_type_percent['totals'] = user_type_percent['total'].sum()

# Calculate the percentage for each user type
user_type_percent['total_percent'] = user_type_percent['total'] / user_type_percent['totals']

# Convert the percentage to a readable format
user_type_percent['percentage%'] = user_type_percent['total_percent'].apply(lambda x: f"{x*100:.2f}%")

# Reorder the levels of the user type
ordered_categories = ["Very active", "Fairly active", "Lightly active", "Sedentary"]
user_type_percent['Activity_Category'] = pd.Categorical(user_type_percent['Activity_Category'], categories=ordered_categories, ordered=True)
user_type_percent = user_type_percent.sort_values('Activity_Category')

user_type_percent
# Out:
#   Activity_Category  total  totals  total_percent percentage%
# 3       Very active      5      24       0.208333      20.83%
# 0     Fairly active      9      24       0.375000      37.50%
# 1    Lightly active      5      24       0.208333      20.83%
# 2         Sedentary      5      24       0.208333      20.83%

# %%
# draw a bar graph for each category
import matplotlib.pyplot as plt

# Data for the pie chart
labels = user_type_percent['Activity_Category']
sizes = user_type_percent['total_percent']

# Plotting the pie chart
plt.figure(figsize=(10, 7))
plt.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=140, colors=['#ff9999','#66b2ff','#99ff99','#ffcc99'])
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.title('Distribution of User Activity Levels')
plt.show()

# %% [markdown]
# Based on the provided results, here are some conclusions we can draw:
#
# 1. **Distribution of User Types**:
#    - The highest percentage of users fall under the "Fairly active" category, making up 37.50% of the total users.
#    - The categories "Very active", "Lightly active", and "Sedentary" each represent 20.83% of the total users, indicating an equal distribution among these three categories.
#
# 2. **Activity Insights**:
#    - Almost 40% of the users are fairly active, suggesting that a significant portion of users are engaging in a moderate amount of physical activity.
#    - The fact that the categories "Very active", "Lightly active", and "Sedentary" have equal distributions might indicate a balanced user base in terms of their activity levels.
#
# 3. **Marketing or Product Development Implications**:
#    - Since "Fairly active" is the most common category, marketing campaigns or product features that target this group might be effective.
#    - Given that there's an equal distribution among the "Very active", "Lightly active", and "Sedentary" categories, it might be worth exploring differentiated marketing strategies or product features tailored to each of these user types.
#
# 4. **User Behavior**:
#    - Despite the availability and capabilities of the smart device, one-fifth of the users are categorized as "Sedentary". This might raise questions about why these users have such devices if they aren't very active. It might be for tracking other health metrics, or perhaps they are looking for motivation to become more active.
#
# In summary, understanding the distribution of user activity levels provides valuable insights into user behavior and can guide decision-making in marketing, product development, and user engagement strategies.

# %% [markdown]
# ### 4.4 Statistical Testing <a class="anchor" id="4_4"></a>
# If you want to determine if the differences in caloric burn between sedentary segments are statistically significant, consider conducting a statistical test like ANOVA.

# %%
import scipy.stats as stats

# Group data by Activity_Category
groups = [daily_avg['mean_daily_calories'][daily_avg['Activity_Category'] == category] for category in ordered_categories]

# Perform ANOVA
f_statistic, p_value = stats.f_oneway(*groups)

print("F statistic: ",f_statistic,"p-value: ", p_value)
# Out:
# F statistic:  0.9150103545405756 p-value:  0.4514558167995676

# %% [markdown]
# There isn't a statistically significant difference in caloric burn between the different user types based on the ANOVA test results. The differences observed in the mean caloric burn for each group could be due to random variation and not due to the group (user type) itself.

# %% [markdown]
# ### 4.5 Trend Analysis <a class="anchor" id="4_5"></a>
# Analyze trends over time. Do users tend to be more active (and burn more calories) on specific days of the week.

# %%
print(daily_activity_calories.columns)
# Out:
# Index(['id', 'activitydate', 'totalsteps', 'totaldistance', 'trackerdistance',
#        'loggedactivitiesdistance', 'veryactivedistance',
#        'moderatelyactivedistance', 'lightactivedistance',
#        'sedentaryactivedistance', 'veryactiveminutes', 'fairlyactiveminutes',
#        'lightlyactiveminutes', 'sedentaryminutes', 'calories_x', 'activityday',
#        'calories_y', 'sleepday', 'totalsleeprecords', 'totalminutesasleep',
#        'totaltimeinbed', 'Sedentary_Segment'],
#       dtype='object')

# %%
print(daily_avg.columns)
# Out:
# Index(['id', 'mean_daily_steps', 'mean_daily_calories', 'mean_daily_sleep',
#        'Activity_Category'],
#       dtype='object')

# %%
# merge daily_avg daily_activity_calories
daily_activity_calories_avg = pd.merge(daily_activity_calories, daily_avg, on='id', how='inner')
daily_activity_calories_avg.head()
# Out:
#            id activitydate  totalsteps  totaldistance  trackerdistance  \
# 0  1503960366   2016-04-12       13162           8.50             8.50
# 1  1503960366   2016-04-13       10735           6.97             6.97
# 2  1503960366   2016-04-15        9762           6.28             6.28
# 3  1503960366   2016-04-16       12669           8.16             8.16
# 4  1503960366   2016-04-17        9705           6.48             6.48
#
#    loggedactivitiesdistance  veryactivedistance  moderatelyactivedistance  \
# 0                       0.0                1.88                      0.55
# 1                       0.0                1.57                      0.69
# 2                       0.0                2.14                      1.26
# 3                       0.0                2.71                      0.41
# 4                       0.0                3.19                      0.78
#
#    lightactivedistance  sedentaryactivedistance  ...  calories_y   sleepday  \
# ...

# %%
most_active_day_mean = daily_activity_calories_avg.groupby('activityday')['totalsteps'].mean()

# Convert the DatetimeIndex to day names
most_active_day_mean_daynames = most_active_day_mean.index.day_name()

# Group by these day names and calculate the mean steps
grouped_day_mean = most_active_day_mean.groupby(most_active_day_mean_daynames).mean()

grouped_day_mean
# Out:
# activityday
# Friday       7935.656693
# Monday       9262.150524
# Saturday     9857.248626
# Sunday       7295.100790
# Thursday     7810.362436
# Tuesday      9183.084799
# Wednesday    8025.138182
# Name: totalsteps, dtype: float64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Ensure the data is sorted by the desired order of days for visual clarity
order_of_days = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']

# Plotting
# Plotting the data using Seaborn
plt.figure(figsize=(10,6))
sns.barplot(x=grouped_day_mean.index, y=grouped_day_mean.values, order=order_of_days, palette="viridis")
plt.title("Average Steps Taken by Day of the Week")
plt.ylabel("Average Steps")
plt.xlabel("Day of the Week")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()


# # Plot Efficiency per Step
# plt.figure(figsize=(10, 5))
# daily_activity_calories_avg.groupby('activitydate')['efficiency_per_step'].mean().plot(kind='bar')
# plt.title('Efficiency per Step by Day')
# plt.ylabel('Efficiency (Calories per Step)')
# plt.xlabel('Day of the Week')
# plt.show()

# %% [markdown]
# Users tend to be most active on weekends, particularly on Saturday.
# Activity starts strong at the beginning of the week with Monday and Tuesday having higher averages, but it seems to decrease slightly mid-week before picking up again towards the weekend.
# This kind of trend could be influenced by various factors such as work schedules, personal habits, or recreational activities that people might engage in more during weekends. This information can be useful for targeted marketing or promotional activities, where you might want to engage users more during their active periods or motivate them during typically less active days.

# %% [markdown]
# ### 4.6 Activity Efficiency <a class="anchor" id="4_6"></a>
# Calculate the "efficiency" of activity, defined as calories burnt per step or per active minute. This can provide insights into which activities or intensity levels yield the highest caloric burn.

# %% [markdown]
# 1. **Calories burnt per step**:
#
# $$
# \text{Efficiency (per step)} = \frac{\text{Total Calories Burnt}}{\text{Total Steps Taken}}
# $$
#
# 2. **Calories burnt per active minute**:
#
# $$
# \text{Efficiency (per minute)} = \frac{\text{Total Calories Burnt}}{\text{Total Active Minutes}}
# $$
#
# Where:
#
# $$
# \text{Total Active Minutes} = \text{Very Active Minutes} + \text{Fairly Active Minutes} + \text{Lightly Active Minutes}
# $$

# %%
daily_activity_calories_avg.head()
# Out:
#            id activitydate  totalsteps  totaldistance  trackerdistance  \
# 0  1503960366   2016-04-12       13162           8.50             8.50
# 1  1503960366   2016-04-13       10735           6.97             6.97
# 2  1503960366   2016-04-15        9762           6.28             6.28
# 3  1503960366   2016-04-16       12669           8.16             8.16
# 4  1503960366   2016-04-17        9705           6.48             6.48
#
#    loggedactivitiesdistance  veryactivedistance  moderatelyactivedistance  \
# 0                       0.0                1.88                      0.55
# 1                       0.0                1.57                      0.69
# 2                       0.0                2.14                      1.26
# 3                       0.0                2.71                      0.41
# 4                       0.0                3.19                      0.78
#
#    lightactivedistance  sedentaryactivedistance  ...  calories_y   sleepday  \
# ...

# %%
# efficieny (per step)
daily_activity_calories_avg["efficiency_per_step"] = daily_activity_calories_avg["calories_y"] / daily_activity_calories_avg["totalsteps"]
# daily_activity_calories_avg.head()
# Calories burnt per active minute:
daily_activity_calories_avg['total_active_minutes'] = daily_activity_calories_avg['veryactiveminutes'] + daily_activity_calories_avg['fairlyactiveminutes'] + daily_activity_calories_avg['lightlyactiveminutes']
daily_activity_calories_avg['efficiency_per_minute'] = daily_activity_calories_avg['calories_y'] / daily_activity_calories_avg['total_active_minutes']
#print columns names
print(daily_activity_calories_avg.columns)
daily_activity_calories_avg.head()
# Out:
# Index(['id', 'activitydate', 'totalsteps', 'totaldistance', 'trackerdistance',
#        'loggedactivitiesdistance', 'veryactivedistance',
#        'moderatelyactivedistance', 'lightactivedistance',
#        'sedentaryactivedistance', 'veryactiveminutes', 'fairlyactiveminutes',
#        'lightlyactiveminutes', 'sedentaryminutes', 'calories_x', 'activityday',
#        'calories_y', 'sleepday', 'totalsleeprecords', 'totalminutesasleep',
#        'totaltimeinbed', 'Sedentary_Segment', 'mean_daily_steps',
#        'mean_daily_calories', 'mean_daily_sleep', 'Activity_Category',
#        'efficiency_per_step', 'total_active_minutes', 'efficiency_per_minute'],
#       dtype='object')
#            id activitydate  totalsteps  totaldistance  trackerdistance  \
# 0  1503960366   2016-04-12       13162           8.50             8.50
# 1  1503960366   2016-04-13       10735           6.97             6.97
# 2  1503960366   2016-04-15        9762           6.28             6.28
# ...

# %%
#Compare efficiencies across different user categories 
# (like "Very Active", "Lightly Active", etc.) to determine which user category is the most efficient.

# Group by User Category and Calculate Efficiency Metrics
# Calculate metrics for each unique user
user_avg_metrics = daily_activity_calories_avg.groupby(['id', 'Activity_Category']).agg({
    'calories_y': 'mean',
    'totalsteps': 'mean',
    'total_active_minutes': 'mean'
}).reset_index()

# Group by User Category and Calculate Efficiency Metrics
user_category_efficiency = user_avg_metrics.groupby('Activity_Category').agg({
    'calories_y': 'mean',
    'totalsteps': 'mean',
    'total_active_minutes': 'mean'
})

user_category_efficiency['efficiency_per_step'] = user_category_efficiency['calories_y'] / user_category_efficiency['totalsteps']
user_category_efficiency['efficiency_per_minute'] = user_category_efficiency['calories_y'] / user_category_efficiency['total_active_minutes']

# %%
#Compare efficiencies across different days to see if there are days
# when users are more efficient in their activities.
# Calculate Efficiency per Step
# Visualization
import matplotlib.pyplot as plt

# Extract day of the week from 'activityday' and create a new column 'day_of_week'
daily_activity_calories_avg['day_of_week'] = daily_activity_calories_avg['activityday'].dt.day_name()

# Plot Efficiency per Step
plt.figure(figsize=(10, 5))
daily_activity_calories_avg.groupby('day_of_week')['efficiency_per_step'].mean().reindex(order_of_days).plot(kind='bar')
plt.title('Efficiency per Step by Day of the Week')
plt.ylabel('Efficiency (Calories per Step)')
plt.xlabel('Day of the Week')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()


# # Plot Efficiency per Active Minute
plt.figure(figsize=(10, 5))
daily_activity_calories_avg.groupby('day_of_week')['efficiency_per_minute'].mean().reindex(order_of_days).plot(kind='bar', color='green')
plt.title('Efficiency per Active Minute by Day')
plt.ylabel('Efficiency (Calories per Minute)')
plt.xlabel('Day of the Week')
plt.show()

# %% [markdown]
# On analyzing the efficiency of calorie burn among users, **Thursday** consistently emerges as the most efficient day, both in terms of calories burned per step and per active minute. This suggests that activities on Thursdays tend to be more intense or effective at burning calories. Conversely, **Monday** appears to be the least efficient day for calorie burn per step, while both **Monday** and **Saturday** show lower efficiency per active minute, indicating potentially more relaxed or less strenuous activities on these days. These patterns might be influenced by specific weekday routines or habits, but a deeper analysis would be required to understand the complete context.

# %% [markdown]
# #### Analyze why sedentary pehave highest efficiency

# %%
# Filter data for sedentary individuals
sedentary_data = daily_activity_calories_avg[daily_activity_calories_avg['Activity_Category'] == 'Sedentary']

# Descriptive statistics for 'totalsteps'
steps_stats = sedentary_data['totalsteps'].describe()
print("Steps Statistics for Sedentary Users:\n", steps_stats)

# Descriptive statistics for 'calories_y' (assuming 'calories_y' is the relevant column for calories)
calories_stats = sedentary_data['calories_y'].describe()
print("\nCalories Statistics for Sedentary Users:\n", calories_stats)
# Out:
# Steps Statistics for Sedentary Users:
#  count      54.000000
# mean     3948.148148
# std      2181.182909
# min       356.000000
# 25%      2271.750000
# 50%      3826.500000
# 75%      5241.750000
# max      9105.000000
# Name: totalsteps, dtype: float64
#
# Calories Statistics for Sedentary Users:
#  count      54.000000
# mean     2208.555556
# std       311.822317
# min      1212.000000
# 25%      2067.000000
# 50%      2191.000000
# 75%      2362.500000
# max      3101.000000
# Name: calories_y, dtype: float64

# %%
# Descriptive statistics for 'veryactiveminutes'
very_active_minutes_stats = sedentary_data['veryactiveminutes'].describe()
print("Very Active Minutes Statistics for Sedentary Users:\n", very_active_minutes_stats)

# Descriptive statistics for 'fairlyactiveminutes'
fairly_active_minutes_stats = sedentary_data['fairlyactiveminutes'].describe()
print("\nFairly Active Minutes Statistics for Sedentary Users:\n", fairly_active_minutes_stats)

# Descriptive statistics for 'lightlyactiveminutes'
lightly_active_minutes_stats = sedentary_data['lightlyactiveminutes'].describe()
print("\nLightly Active Minutes Statistics for Sedentary Users:\n", lightly_active_minutes_stats)
# Out:
# Very Active Minutes Statistics for Sedentary Users:
#  count    54.000000
# mean      4.370370
# std       9.697882
# min       0.000000
# 25%       0.000000
# 50%       0.000000
# 75%       0.000000
# max      34.000000
# Name: veryactiveminutes, dtype: float64
#
# Fairly Active Minutes Statistics for Sedentary Users:
#  count    54.000000
# mean      3.814815
# std       8.584923
# min       0.000000
# 25%       0.000000
# 50%       0.000000
# 75%       1.750000
# max      45.000000
# Name: fairlyactiveminutes, dtype: float64
#
# Lightly Active Minutes Statistics for Sedentary Users:
#  count     54.000000
# mean     176.388889
# std       83.241730
# min       32.000000
# 25%      109.000000
# 50%      182.000000
# 75%      231.000000
# max      380.000000
# Name: lightlyactiveminutes, dtype: float64

# %%
# Descriptive statistics for 'totalminutesasleep'
sleep_stats = sedentary_data['totalminutesasleep'].describe()
print("Sleep Statistics for Sedentary Users:\n", sleep_stats)

# Descriptive statistics for 'totaltimeinbed'
time_in_bed_stats = sedentary_data['totaltimeinbed'].describe()
print("\nTime in Bed Statistics for Sedentary Users:\n", time_in_bed_stats)
# Out:
# Sleep Statistics for Sedentary Users:
#  count     54.000000
# mean     415.000000
# std      118.194755
# min       98.000000
# 25%      361.500000
# 50%      416.000000
# 75%      462.000000
# max      750.000000
# Name: totalminutesasleep, dtype: float64
#
# Time in Bed Statistics for Sedentary Users:
#  count     54.000000
# mean     456.611111
# std      162.977880
# min      107.000000
# 25%      391.000000
# 50%      432.000000
# 75%      500.500000
# max      961.000000
# Name: totaltimeinbed, dtype: float64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Setting the style for the plot
sns.set_style("whitegrid")

# Creating a boxplot
plt.figure(figsize=(12, 7))
sns.boxplot(x="Activity_Category", y="totalminutesasleep", data=daily_activity_calories_avg, order=["Sedentary", "Lightly active", "Fairly active", "Very active"])

plt.title('Comparison of Total Minutes Asleep for Different Activity Categories')
plt.ylabel('Total Minutes Asleep')
plt.xlabel('Activity Category')
plt.show()

# statistical summary
daily_activity_calories_avg.groupby('Activity_Category')['totalminutesasleep'].describe()
# Out:
#                    count        mean         std   min    25%    50%     75%  \
# Activity_Category
# Fairly active      188.0  434.537234  106.480817  74.0  392.0  437.0  482.25
# Lightly active      65.0  454.753846  133.668904  58.0  461.0  501.0  523.00
# Sedentary           54.0  415.000000  118.194755  98.0  361.5  416.0  462.00
# Very active        103.0  370.864078  116.497837  62.0  299.5  368.0  445.00
#
#                      max
# Activity_Category
# Fairly active      796.0
# Lightly active     692.0
# Sedentary          750.0
# Very active        700.0

# %%
# The average calories burned for each category of activity
plt.figure(figsize=(10, 6))
sns.barplot(x='Activity_Category', y='mean_daily_calories', data=daily_activity_calories_avg, palette="viridis")
plt.title('Average Calories Burned per Activity Category')
plt.ylabel('Average Daily Calories')
plt.xlabel('Activity Category')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# 
daily_activity_calories_avg.groupby('Activity_Category')['mean_daily_calories'].describe()
# Out:
#                    count         mean         std          min          25%  \
# Activity_Category
# Fairly active      188.0  2640.590426  673.545614  1875.677419  1982.032258
# Lightly active      65.0  1960.753846  520.339873  1540.785714  1540.785714
# Sedentary           54.0  2208.555556  144.391269  1676.333333  2183.142857
# Very active        103.0  2295.815534  644.053927  1560.392857  1560.392857
#
#                            50%          75%          max
# Activity_Category
# Fairly active      2460.833333  3436.580645  3539.192308
# Lightly active     2024.692308  2024.692308  3195.000000
# Sedentary          2183.142857  2299.333333  2344.666667
# Very active        1872.280000  2899.682065  3309.333333

# %% [markdown]
# ### 4.7 Caloric Goals <a class="anchor" id="4_7"></a>
#
# If there's a recommended daily caloric burn (e.g., 2000 calories/day), determine the percentage of days users meet or exceed this goal.

# %%
# 1. Set the caloric goal
caloric_goal = 2000

# 2. Determine days meeting the goal
daily_activity_calories_avg['meets_goal'] = daily_activity_calories_avg['calories_y'] >= caloric_goal

# 3. Calculate the percentage
percentage_meeting_goal = (daily_activity_calories_avg['meets_goal'].sum() / len(daily_activity_calories_avg)) * 100

print(f"The percentage of days users meet or exceed the caloric goal is: {percentage_meeting_goal:.2f}%")
# Out:
# The percentage of days users meet or exceed the caloric goal is: 65.12%

# %% [markdown]
# Approximately 65.12% of users consistently meet or surpass the recommended daily caloric burn of 2000 calories. This suggests that a majority are actively engaging in sufficient physical activities.

# %% [markdown]
# # <span>  5. Share and Act </span>  <a class="anchor" id="Share_and_Act_5"></a>

# %% [markdown]
# ### 5.1 Conclusion <a class="anchor" id="Conclusion_5_1"></a>
#
# 1. **Activity Levels**: A significant portion of users are classified as "Fairly active" with a noticeable balance among the "Very active", "Lightly active", and "Sedentary" categories. This suggests a diverse user base in terms of activity levels.
# 2. **Activity Trends**: Saturdays are the most active days for users in terms of steps, while Sundays are the least active. This implies weekend habits vary, with users being more active at the start of the weekend and slowing down by its end.
# 3. **Activity Efficiency**: Users tend to be more calorie-efficient on Thursdays. This might be due to varying intensity levels or types of activities they engage in. Surprisingly, "Sedentary" users had a higher efficiency in calories burned per step, which might be due to non-step related activities or errors in data logging.
# 4. **Caloric Goals**: A majority (65.12%) of days witnessed users meeting or exceeding a hypothetical caloric goal of 2000 calories/day.
# 5. **Logged Activities and Calories**: There's a positive relationship between the distance of logged activities and the total calories burned.
#
# ### 5.2 Application of Insights <a class="anchor" id="Application_of_Insights_5_2"></a>
# 1. **Targeted Marketing and Product Features**: Knowing the activity habits of users can guide targeted marketing campaigns. For instance, motivating messages or challenges can be sent on Sundays to boost activity.
# 2. **Enhanced Features**: The surprising efficiency of "Sedentary" users can be further explored, possibly leading to new features that track non-step-based activities more effectively.
# 3. **Goal Setting Features**: With many users reaching or exceeding caloric burn goals, the app could introduce dynamic goal-setting features to challenge users based on their past performance.
#
# ### 5.3 Next Steps <a class="anchor" id="Next_Steps_5_3"></a>
# 1. **Deep Dive into Sedentary Efficiency**: Investigate why "Sedentary" users have a high efficiency. Are there specific activities they log that are not based on steps but burn more calories?
# 2. **User Feedback**: Consider surveys or feedback mechanisms to understand user behavior better, especially around the patterns observed, such as activity dips on Sundays.
# 3. **Testing and Iteration**: Based on these insights, pilot new app features or marketing campaigns and measure their impact on user activity and engagement. For instance, introduce challenges or badges for users who consistently meet their caloric goals.
# 4. **Further Analysis**: Dive into other datasets (if available) to analyze other aspects of user health and behavior, such as sleep patterns, heart rate variations, and more.
